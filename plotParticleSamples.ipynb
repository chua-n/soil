# %%
import os
from skimage import io
import numpy as np

from particle.utils.plotter import makeGrid

# %%
folder = "data/liutao/v1/views/00001-10000/"
filenames = os.listdir(folder)
filenames.sort()
filenames[:15]
filenames = filenames[:3000]

# %%
sample = io.imread(os.path.join(folder, filenames[0]))
io.imshow(sample)

# %%
imgs = np.empty((len(filenames), *sample.shape), dtype=sample.dtype)
for img, filename in zip(imgs, filenames):
    img[:] = io.imread(os.path.join(folder, filename))

# %%
initInd = 600 # real
# initInd = 2718 # gan
# initInd = 271 # vae
makeGrid(imgs[initInd:initInd+25], "/home/chuan/samples.png", nrow=5)
